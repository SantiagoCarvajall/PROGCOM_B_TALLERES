# %% [markdown]
# Punto 1 For

# %%
num=int(input("Escriba un numero: "))

for n in range(0, num+1):
  if num %1==0:
   print("Es primo")
  elif num %2!=0:
     print("No es primo")
# Out:
# Escriba un numero: 1
# Es primo
# Es primo
